# %% [markdown]
# # f2e_inj initial electron distribution

# %%
# %pylab --no-import-all inline
# %config InlineBackend.figure_format = 'retina'
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from distgen import Generator

# %%
G = Generator('v0/distgen.yaml')
G['distgen:total_charge:value'], G['distgen:total_charge:units']
# Out:
# (2000, 'pC')

# %%
G.run()
P0 = G.particles
P0
# Out:
# <ParticleGroup with 1000000 particles at 0x1633c0e80>

# %%
P0.plot('x', 'y', figsize=(5,5))

# %%
P0.plot('t', 'p', figsize=(5,5))
