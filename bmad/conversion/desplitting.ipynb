# %% [markdown]
# # FACET-II Linac de-splitting

# %%
from pytao import Tao
from pprint import pprint
import json

# %%
M = Tao('-init $FACET2_LATTICE/bmad/models/f2_elec/tao.init -noplot')

# %%
# %%tao
# python lat_list 1@0>>Q*|base real:ele.s
# Out:
# -------------------------
# Tao> python lat_list 1@0>>Q*|base real:ele.s
# -------------------------
# Tao>

# %%
SLIST = M.cmd_real('python lat_list -track_only 1@0>>*|model real:ele.s')
LLIST = M.cmd_real('python lat_list -track_only  1@0>>*|model real:ele.l')
NAMES = M.cmd('python lat_list -track_only 1@0>>*|model ele.name')
IXLIST = [i for i in range(len(NAMES))]

ix_of = {}
for ix, name in enumerate(NAMES):
    if name in ix_of:
        pass
#        print("err", name)
    else: 
        ix_of[name] = ix

for s, l, n in zip(SLIST[0:20], LLIST[0:20], NAMES[0:20]):
    print (n, l, s)
# Out:
# BEGINNING 0.0 0.0
# DL00 -0.8690480010000002 -0.8690480010000002
# LOADLOCKF 0.8690480010000002 0.0
# BEGINJ 0.0 0.0
# SOL10111 0.0 0.0
# CATHODEF 0.0 0.0
# DL01A 0.0972947 0.0972947
# SOL10121#1 0.1 0.1972947
# YC10122 0.0 0.1972947
# XC10121 0.0 0.1972947
# SQ10122 0.0 0.1972947
# CQ10121 0.0 0.1972947
# SOL10121#2 0.1 0.2972947
# DL01B 0.0785101 0.37580480000000005
# VV10155 0.0 0.37580480000000005
# DL01C 0.1160862 0.4918910000000001
# MIR10181 0.0 0.4918910000000001
# DL01D 0.0811358 0.5730268000000001
# VV10215 0.0 0.5730268000000001
# DL01E 0.1263224 0.6993492000000001

# %%
# Search for split eles

def find_split_eles(slist, llist, names):
    """
    Searches for split elements
    
    """

    split_eles = {}
    basename = 'xxx'
    split_eles[basename] = {'stubs':[], 'splits':[], 'offsets':[]}
    stubs  = split_eles[basename]['stubs']
    splits = split_eles[basename]['splits']
    offsets = split_eles[basename]['offsets']
    s0 = 0
    for s, l, n in zip(SLIST, LLIST, NAMES):
        
        if l == 0:
            splits.append(n)
            offsets.append(s - s0)
        # Thick ele
        elif n.startswith(basename) and len(n)==len(basename)+1:
            # this is a true split ele     
            stubs.append(n)
            split_eles[basename]['L'] += l
        else:
            # New thick ele
            
            # Removing unwanted eles
            if basename == 'K21_3B':
                # Special case. Leave these
                print(basename, stubs, splits)
                pass
            elif len(stubs) == 1 or len(splits) == 0:
                split_eles.pop(basename)
            # Or if this is obviously a superimpose element
            elif basename.endswith('#'):
                split_eles.pop(basename)
                
            # Try a basename which excludes the final character
            basename = n[:-1]
            split_eles[basename] = {'stubs':[], 'splits':[], 'offsets':[]}
            split_eles[basename]['L'] = l
            s0 = s -l 
            stubs  = split_eles[basename]['stubs']
            splits = split_eles[basename]['splits']
            offsets = split_eles[basename]['offsets']
            stubs.append(n) # add this 
    
        #print (n, l, s, ix)
        
    split_eles.pop('xxx')        
    
    return split_eles

SPLIT_ELES = find_split_eles(SLIST, LLIST, NAMES)
    
pprint(SPLIT_ELES)
# Out:
# {'D11OD': {'L': 0.2884622642981027,
#            'offsets': [0.1312309357279986],
#            'splits': ['CE11345'],
#            'stubs': ['D11OD1', 'D11OD2']},
#  'D199': {'L': 4.879374683414004,
#           'offsets': [4.570883999999978,
#                       4.879374683413971,
#                       4.879374683413971,
#                       4.879374683413971],
#           'splits': ['IM1988', 'LI19TERM', 'ENDL3F_2', 'BEGBC20'],
#           'stubs': ['D199C', 'D199D']},
#  'D199A': {'L': 1.1216,
#            'offsets': [0.8016000000000076, 1.1216000000000577],
#            'splits': ['XC19900', 'YC19900'],
#            'stubs': ['D199A1', 'D199A2']},
#  'D1ET1': {'L': 3.8659737036155786,
#            'offsets': [2.8210129999999936, 3.865973703615623],
#            'splits': ['XC1996', 'IM2040'],
#            'stubs': ['D1ET1A', 'D1ET1B']},
#  'D1ET2': {'L': 3.8684887036155784,
#            'offsets': [2.452947999999992],
#            'splits': ['XC2460'],
#            'stubs': ['D1ET2A', 'D1ET2B']},
#  'D210B': {'L': 0.2,
#            'offsets': [0.10000000000002274],
#            'splits': ['CE14815'],
#            'stubs': ['D210B1', 'D210B2']},
#  'D5EC1': {'L': 1.474589,
#            'offsets': [0.7450559999999768],
#            'splits': ['YC2181'],
#            'stubs': ['D5EC1A', 'D5EC1B']},
#  'D5EC2': {'L': 1.47545,
#            'offsets': [0.8903549999999996],
#            'splits': ['YC2321'],
#            'stubs': ['D5EC2A', 'D5EC2B']},
#  'DAQ4': {'L': 2.5527,
#           'offsets': [0.22295199999996385,
#                       0.6666900000000169,
#                       0.9855999999999767,
#                       0.9855999999999767,
#                       2.552699999999959,
#                       2.552699999999959],
#           'splits': ['BL18900',
#                      'WS18944',
#                      'CX18960',
#                      'CY18960',
#                      'LI18END',
#                      'LI19BEG'],
#           'stubs': ['DAQ4K', 'DAQ4L', 'DAQ4M', 'DAQ4N']},
#  'DAQ5': {'L': 0.1748999999999996,
#           'offsets': [0.10000000000002274],
#           'splits': ['WS19344'],
#           'stubs': ['DAQ5A', 'DAQ5B']},
#  'DB00': {'L': 0.7263999999999999,
#           'offsets': [0.3996999999999993,
#                       0.5607000000000006,
#                       0.5607000000000006],
#           'splits': ['PR10711', 'XC10721', 'YC10722'],
#           'stubs': ['DB00A', 'DB00B', 'DB00C']},
#  'DDG1': {'L': 0.8302,
#           'offsets': [0.24864000000000175, 0.5957059999999998],
#           'splits': ['BPM11333', 'PR11335'],
#           'stubs': ['DDG11', 'DDG12', 'DDG13', 'DDG14']},
#  'DDG2': {'L': 0.4171,
#           'offsets': [0.18260600000002114],
#           'splits': ['PR14803'],
#           'stubs': ['DDG23', 'DDG24']},
#  'DE01': {'L': 0.293513,
#           'offsets': [0.07637300000000025, 0.1987319999999997],
#           'splits': ['IM10431', 'VV10435'],
#           'stubs': ['DE01A', 'DE01B', 'DE01C']},
#  'DE03': {'L': 0.2819662,
#           'offsets': [0.14546720000000057, 0.14546720000000057],
#           'splits': ['XC10521', 'YC10522'],
#           'stubs': ['DE03A', 'DE03B']},
#  'DE04': {'L': 0.411914814698,
#           'offsets': [0.2904141540519998, 0.4119148146979992],
#           'splits': ['VV10545', 'WALLBEG'],
#           'stubs': ['DE04A', 'DE04B']},
#  'DE05': {'L': 1.6263334337200002,
#           'offsets': [0.1649864943899999,
#                       0.5567311185870008,
#                       0.7067311185870011],
#           'splits': ['BPM10581', 'IM10591', 'BZ10596'],
#           'stubs': ['DE05D', 'DE05E', 'DE05F', 'DE05G']},
#  'DE05C': {'L': 0.215468253984,
#            'offsets': [0.1077341269919998, 0.2154682539839996],
#            'splits': ['MRK0F', 'PR10571'],
#            'stubs': ['DE05C1', 'DE05C2']},
#  'DE06': {'L': 0.4478221,
#           'offsets': [0.14787210000000073, 0.14787210000000073],
#           'splits': ['XC10641', 'YC10642'],
#           'stubs': ['DE06A', 'DE06B']},
#  'DEX20_': {'L': 2.252982138228781,
#             'offsets': [0.07298213822878097,
#                         0.3329821382287719,
#                         0.4329821382287946,
#                         0.49298213822874004,
#                         0.6129821382287446,
#                         1.3329821382287719,
#                         1.7346821382287771,
#                         1.786682138228798,
#                         2.2529821382288446],
#             'splits': ['EXTHOLE1',
#                        'USOTR',
#                        'IQMON20',
#                        'BEWIN1',
#                        'LCUBE',
#                        'PIC_CENT',
#                        'FILG',
#                        'FILS',
#                        'IPOTR1P'],
#             'stubs': ['DEX20_1',
#                       'DEX20_2',
#                       'DEX20_3',
#                       'DEX20_4',
#                       'DEX20_5',
#                       'DEX20_6',
#                       'DEX20_7',
#                       'DEX20_8',
#                       'DEX20_9']},
#  'DEX20_1': {'L': 1.19,
#              'offsets': [0.8999999999999773,
#                          1.009999999999991,
#                          1.0599999999999454,
#                          1.1899999999999409,
#                          1.1899999999999409,
#                          1.1899999999999409],
#              'splits': ['IM3255',
#                         'BEWIN2',
#                         'IPWS3',
#                         'DSOTR',
#                         'ENDEXPT20',
#                         'BEGSPECT20'],
#              'stubs': ['DEX20_13', 'DEX20_14', 'DEX20_15', 'DEX20_16']},
#  'DH02': {'L': 0.1487289793,
#           'offsets': [0.08096785290000064],
#           'splits': ['PR10465'],
#           'stubs': ['DH02A', 'DH02B']},
#  'DH03': {'L': 0.1422609708,
#           'offsets': [0.06767921119999976],
#           'splits': ['PR10471'],
#           'stubs': ['DH03A', 'DH03B']},
#  'DKRK': {'L': 0.923223,
#           'offsets': [0.6919360000000552, 0.9232230000000072],
#           'splits': ['KRK', 'YC2FF'],
#           'stubs': ['DKRK1', 'DKRK2']},
#  'DL01': {'L': 0.7349089999999999,
#           'offsets': [0.07851010000000003,
#                       0.19459630000000006,
#                       0.27573210000000004,
#                       0.4020545000000001,
#                       0.4105635000000001,
#                       0.4105635000000001,
#                       0.6447896000000001,
#                       0.7349090000000001,
#                       0.7349090000000001],
#           'splits': ['VV10155',
#                      'MIR10181',
#                      'VV10215',
#                      'BPM10221',
#                      'XC10221',
#                      'YC10222',
#                      'PR10241',
#                      'L0AFBEG',
#                      'FLNGAF1'],
#           'stubs': ['DL01B',
#                     'DL01C',
#                     'DL01D',
#                     'DL01E',
#                     'DL01F',
#                     'DL01G',
#                     'DL01H']},
#  'DL03': {'L': 0.22037600000000002,
#           'offsets': [0.09448399999999957],
#           'splits': ['PH10365'],
#           'stubs': ['DL03A', 'DL03B']},
#  'DM00': {'L': 0.361983,
#           'offsets': [0.22129999999999939, 0.22129999999999939],
#           'splits': ['XC10761', 'YC10762'],
#           'stubs': ['DM00A', 'DM00B']},
#  'DM02': {'L': 0.297648,
#           'offsets': [0.1402000000000001,
#                       0.19764800000000093,
#                       0.29764800000000236,
#                       0.29764800000000236],
#           'splits': ['IM10791', 'VV10795', 'ENDDL10', 'BEGL1F'],
#           'stubs': ['DM02A', 'DM02B', 'DM02C']},
#  'DM14': {'L': 0.56418875,
#           'offsets': [0.3847239999999985, 0.3847239999999985],
#           'splits': ['BL11359', 'IM11360'],
#           'stubs': ['DM14A', 'DM14B']},
#  'DM15': {'L': 4.8138300535609995,
#           'offsets': [0.3521459999999976,
#                       2.5071850354209957,
#                       4.325643053560995],
#           'splits': ['YC11365', 'PR11375', 'TD11390'],
#           'stubs': ['DM15A', 'DM15B', 'DM15C', 'DM15D']},
#  'DM21': {'L': 1.9339006,
#           'offsets': [1.4366001999999867],
#           'splits': ['VV14711'],
#           'stubs': ['DM21A', 'DM21B']},
#  'DM23': {'L': 0.854865382243,
#           'offsets': [0.5131653822430167, 0.5131653822430167],
#           'splits': ['VV14885', 'BL14888'],
#           'stubs': ['DM23A', 'DM23B', 'DM23C']},
#  'DM24': {'L': 0.5552,
#           'offsets': [0.3065000000000282],
#           'splits': ['IM14895'],
#           'stubs': ['DM24A', 'DM24B']},
#  'DXC1': {'L': 0.52755,
#           'offsets': [0.12999999999999545],
#           'splits': ['XC1E'],
#           'stubs': ['DXC1E', 'DXC1E', 'DXC1B']},
#  'DXC2': {'L': 0.26,
#           'offsets': [0.12999999999999545],
#           'splits': ['XC2E'],
#           'stubs': ['DXC2E', 'DXC2E']},
#  'DXC3': {'L': 0.26,
#           'offsets': [0.12999999999999545],
#           'splits': ['XC3E'],
#           'stubs': ['DXC3E', 'DXC3E']},
#  'DXC4': {'L': 0.26,
#           'offsets': [0.12999999999999545],
#           'splits': ['XC4E'],
#           'stubs': ['DXC4E', 'DXC4E']},
#  'DYAG': {'L': 0.480114255998,
#           'offsets': [0.2669816104549909],
#           'splits': ['SYAG'],
#           'stubs': ['DYAGW', 'DYAGQ']},
#  'DYC1': {'L': 0.26,
#           'offsets': [0.12999999999999545],
#           'splits': ['YC1E'],
#           'stubs': ['DYC1E', 'DYC1E']},
#  'DYC2': {'L': 0.136,
#           'offsets': [0.06799999999998363],
#           'splits': ['YC2E'],
#           'stubs': ['DYC2E', 'DYC2E']},
#  'DYC3': {'L': 0.136,
#           'offsets': [0.06799999999998363],
#           'splits': ['YC3E'],
#           'stubs': ['DYC3E', 'DYC3E']},
#  'K11_2A': {'L': 3.0441000000000003,
#             'offsets': [0.32560000000000144, 0.6126000000000005],
#             'splits': ['XC11202', 'YC11203'],
#             'stubs': ['K11_2A1', 'K11_2A2', 'K11_2A3']},
#  'K11_4A': {'L': 2.1694,
#             'offsets': [0.32679999999999865, 0.5767999999999986],
#             'splits': ['XC11402', 'YC11403'],
#             'stubs': ['K11_4A1', 'K11_4A2', 'K11_4A3']},
#  'K11_6A': {'L': 2.1694,
#             'offsets': [0.32800000000000296, 0.578000000000003],
#             'splits': ['XC11602', 'YC11603'],
#             'stubs': ['K11_6A1', 'K11_6A2', 'K11_6A3']},
#  'K12_2A': {'L': 2.1694,
#             'offsets': [0.32800000000000296, 0.578000000000003],
#             'splits': ['XC12202', 'YC12203'],
#             'stubs': ['K12_2A1', 'K12_2A2', 'K12_2A3']},
#  'K12_3A': {'L': 3.0441,
#             'offsets': [0.3311999999999955, 0.5811999999999955],
#             'splits': ['XC12302', 'YC12303'],
#             'stubs': ['K12_3A1', 'K12_3A2', 'K12_3A3']},
#  'K12_4A': {'L': 3.0441,
#             'offsets': [0.32679999999999154, 0.5767999999999915],
#             'splits': ['XC12402', 'YC12403'],
#             'stubs': ['K12_4A1', 'K12_4A2', 'K12_4A3']},
#  'K12_5A': {'L': 3.0441000000000003,
#             'offsets': [0.3324000000000069, 0.5824000000000069],
#             'splits': ['XC12502', 'YC12503'],
#             'stubs': ['K12_5A1', 'K12_5A2', 'K12_5A3']},
#  'K12_6A': {'L': 3.0441000000000003,
#             'offsets': [0.32800000000000296, 0.7609999999999957],
#             'splits': ['XC12602', 'YC12603'],
#             'stubs': ['K12_6A1', 'K12_6A2', 'K12_6A3']},
#  'K12_7A': {'L': 3.0441000000000003,
#             'offsets': [0.3335999999999899, 0.6910999999999774],
#             'splits': ['XC12702', 'YC12703'],
#             'stubs': ['K12_7A1', 'K12_7A2', 'K12_7A3']},
#  'K12_8A': {'L': 3.0441000000000003,
#             'offsets': [0.32919999999998595, 0.7323999999999842],
#             'splits': ['XC12802', 'YC12803'],
#             'stubs': ['K12_8A1', 'K12_8A2', 'K12_8A3']},
#  'K12_8D': {'L': 3.0441,
#             'offsets': [2.386899999999997, 2.636899999999997],
#             'splits': ['XC12900', 'YC12900'],
#             'stubs': ['K12_8D1', 'K12_8D2', 'K12_8D3']},
#  'K13_2A': {'L': 3.0441,
#             'offsets': [0.32560000000000855, 0.7102000000000146],
#             'splits': ['XC13202', 'YC13203'],
#             'stubs': ['K13_2A1', 'K13_2A2', 'K13_2A3']},
#  'K13_3A': {'L': 3.0441000000000003,
#             'offsets': [0.3311999999999955, 0.7134000000000071],
#             'splits': ['XC13302', 'YC13303'],
#             'stubs': ['K13_3A1', 'K13_3A2', 'K13_3A3']},
#  'K13_4A': {'L': 3.0441,
#             'offsets': [0.32679999999999154, 0.7769000000000119],
#             'splits': ['XC13402', 'YC13403'],
#             'stubs': ['K13_4A1', 'K13_4A2', 'K13_4A3']},
#  'K13_5A': {'L': 3.0441000000000003,
#             'offsets': [0.3324000000000069, 0.5824000000000069],
#             'splits': ['XC13502', 'YC13503'],
#             'stubs': ['K13_5A1', 'K13_5A2', 'K13_5A3']},
#  'K13_6A': {'L': 3.0441000000000003,
#             'offsets': [0.32799999999997453, 0.5779999999999745],
#             'splits': ['XC13602', 'YC13603'],
#             'stubs': ['K13_6A1', 'K13_6A2', 'K13_6A3']},
#  'K13_7A': {'L': 3.0441000000000003,
#             'offsets': [0.3335999999999899, 0.5835999999999899],
#             'splits': ['XC13702', 'YC13703'],
#             'stubs': ['K13_7A1', 'K13_7A2', 'K13_7A3']},
#  'K13_8A': {'L': 3.0441000000000003,
#             'offsets': [0.32920000000001437, 0.7356000000000336],
#             'splits': ['XC13802', 'YC13803'],
#             'stubs': ['K13_8A1', 'K13_8A2', 'K13_8A3']},
#  'K13_8D': {'L': 3.0441,
#             'offsets': [2.3869000000000256, 2.6369000000000256],
#             'splits': ['XC13900', 'YC13900'],
#             'stubs': ['K13_8D1', 'K13_8D2', 'K13_8D3']},
#  'K14_2A': {'L': 3.0441000000000003,
#             'offsets': [0.32560000000000855, 0.5756000000000085],
#             'splits': ['XC14202', 'YC14203'],
#             'stubs': ['K14_2A1', 'K14_2A2', 'K14_2A3']},
#  'K14_3A': {'L': 3.0441000000000003,
#             'offsets': [0.3312000000000239, 0.732400000000041],
#             'splits': ['XC14302', 'YC14303'],
#             'stubs': ['K14_3A1', 'K14_3A2', 'K14_3A3']},
#  'K14_4A': {'L': 3.0441,
#             'offsets': [0.32679999999999154, 0.5767999999999915],
#             'splits': ['XC14402', 'YC14403'],
#             'stubs': ['K14_4A1', 'K14_4A2', 'K14_4A3']},
#  'K14_5A': {'L': 3.0441000000000003,
#             'offsets': [0.3324000000000069, 0.5824000000000069],
#             'splits': ['XC14502', 'YC14503'],
#             'stubs': ['K14_5A1', 'K14_5A2', 'K14_5A3']},
#  'K14_6A': {'L': 3.0441000000000003,
#             'offsets': [0.32799999999997453, 0.7323999999999842],
#             'splits': ['XC14602', 'YC14603'],
#             'stubs': ['K14_6A1', 'K14_6A2', 'K14_6A3']},
#  'K14_6D': {'L': 3.0441000000000003,
#             'offsets': [2.3321000000000254,
#                         2.6369000000000256,
#                         3.0441000000000145,
#                         3.0441000000000145,
#                         3.0441000000000145],
#             'splits': ['XC14702', 'YC14703', 'LI14TERM', 'ENDL2F', 'BEGBC14_1'],
#             'stubs': ['K14_6D1', 'K14_6D2', 'K14_6D3']},
#  'K15_1A': {'L': 3.0441000000000003,
#             'offsets': [0.3299999999999841, 0.5799999999999841],
#             'splits': ['XC14900', 'YC14900'],
#             'stubs': ['K15_1A1', 'K15_1A2', 'K15_1A3']},
#  'K15_2A': {'L': 3.0441000000000003,
#             'offsets': [0.32560000000000855, 0.5756000000000085],
#             'splits': ['XC15202', 'YC15203'],
#             'stubs': ['K15_2A1', 'K15_2A2', 'K15_2A3']},
#  'K15_3A': {'L': 3.0441000000000003,
#             'offsets': [0.3312000000000239, 0.7356000000000336],
#             'splits': ['XC15302', 'YC15303'],
#             'stubs': ['K15_3A1', 'K15_3A2', 'K15_3A3']},
#  'K15_4A': {'L': 3.0441,
#             'offsets': [0.32679999999999154, 0.5767999999999915],
#             'splits': ['XC15402', 'YC15403'],
#             'stubs': ['K15_4A1', 'K15_4A2', 'K15_4A3']},
#  'K15_5A': {'L': 3.0441000000000003,
#             'offsets': [0.3324000000000069, 0.7261000000000308],
#             'splits': ['XC15502', 'YC15503'],
#             'stubs': ['K15_5A1', 'K15_5A2', 'K15_5A3']},
#  'K15_6A': {'L': 3.0441000000000003,
#             'offsets': [0.32799999999997453, 0.5779999999999745],
#             'splits': ['XC15602', 'YC15603'],
#             'stubs': ['K15_6A1', 'K15_6A2', 'K15_6A3']},
#  'K15_7A': {'L': 3.0441000000000003,
#             'offsets': [0.3335999999999899, 0.5835999999999899],
#             'splits': ['XC15702', 'YC15703'],
#             'stubs': ['K15_7A1', 'K15_7A2', 'K15_7A3']},
#  'K15_8A': {'L': 3.0441000000000003,
#             'offsets': [0.32920000000001437, 0.7705000000000268],
#             'splits': ['XC15802', 'YC15803'],
#             'stubs': ['K15_8A1', 'K15_8A2', 'K15_8A3']},
#  'K15_8D': {'L': 3.0441,
#             'offsets': [2.3868999999999687, 2.6368999999999687],
#             'splits': ['XC15900', 'YC15900'],
#             'stubs': ['K15_8D1', 'K15_8D2', 'K15_8D3']},
#  'K16_2A': {'L': 3.0441000000000003,
#             'offsets': [0.32560000000000855, 0.6911000000000058],
#             'splits': ['XC16202', 'YC16203'],
#             'stubs': ['K16_2A1', 'K16_2A2', 'K16_2A3']},
#  'K16_3A': {'L': 3.0441,
#             'offsets': [0.3311999999999671, 0.5811999999999671],
#             'splits': ['XC16302', 'YC16303'],
#             'stubs': ['K16_3A1', 'K16_3A2', 'K16_3A3']},
#  'K16_4A': {'L': 3.0441000000000003,
#             'offsets': [0.3268000000000484, 0.6942999999999984],
#             'splits': ['XC16402', 'YC16403'],
#             'stubs': ['K16_4A1', 'K16_4A2', 'K16_4A3']},
#  'K16_5A': {'L': 3.0441000000000003,
#             'offsets': [0.3324000000000069, 0.6974999999999909],
#             'splits': ['XC16502', 'YC16503'],
#             'stubs': ['K16_5A1', 'K16_5A2', 'K16_5A3']},
#  'K16_6A': {'L': 3.0441000000000003,
#             'offsets': [0.32799999999997453, 0.7418999999999869],
#             'splits': ['XC16602', 'YC16603'],
#             'stubs': ['K16_6A1', 'K16_6A2', 'K16_6A3']},
#  'K16_7A': {'L': 3.0441000000000003,
#             'offsets': [0.33360000000004675, 0.7229000000000951],
#             'splits': ['XC16702', 'YC16703'],
#             'stubs': ['K16_7A1', 'K16_7A2', 'K16_7A3']},
#  'K16_8A': {'L': 3.0441000000000003,
#             'offsets': [0.32920000000001437, 0.5792000000000144],
#             'splits': ['XC16802', 'YC16803'],
#             'stubs': ['K16_8A1', 'K16_8A2', 'K16_8A3']},
#  'K16_8D': {'L': 3.0441,
#             'offsets': [2.3868999999999687, 2.6368999999999687],
#             'splits': ['XC16900', 'YC16900'],
#             'stubs': ['K16_8D1', 'K16_8D2', 'K16_8D3']},
#  'K17_2A': {'L': 3.0441000000000003,
#             'offsets': [0.32560000000000855, 0.7069999999999936],
#             'splits': ['XC17202', 'YC17203'],
#             'stubs': ['K17_2A1', 'K17_2A2', 'K17_2A3']},
#  'K17_3A': {'L': 3.0441,
#             'offsets': [0.3311999999999671, 0.5811999999999671],
#             'splits': ['XC17302', 'YC17303'],
#             'stubs': ['K17_3A1', 'K17_3A2', 'K17_3A3']},
#  'K17_4A': {'L': 3.0441,
#             'offsets': [0.3268000000000484, 0.5768000000000484],
#             'splits': ['XC17402', 'YC17403'],
#             'stubs': ['K17_4A1', 'K17_4A2', 'K17_4A3']},
#  'K17_5A': {'L': 3.0441,
#             'offsets': [0.3324000000000069, 0.7164999999999964],
#             'splits': ['XC17502', 'YC17503'],
#             'stubs': ['K17_5A1', 'K17_5A2', 'K17_5A3']},
#  'K17_6A': {'L': 3.0441000000000003,
#             'offsets': [0.32799999999997453, 0.7228999999999814],
#             'splits': ['XC17602', 'YC17603'],
#             'stubs': ['K17_6A1', 'K17_6A2', 'K17_6A3']},
#  'K17_7A': {'L': 3.0441000000000003,
#             'offsets': [0.33360000000004675, 0.5836000000000467],
#             'splits': ['XC17702', 'YC17703'],
#             'stubs': ['K17_7A1', 'K17_7A2', 'K17_7A3']},
#  'K17_8A': {'L': 3.0441000000000003,
#             'offsets': [0.32920000000001437, 0.5792000000000144],
#             'splits': ['XC17802', 'YC17803'],
#             'stubs': ['K17_8A1', 'K17_8A2', 'K17_8A3']},
#  'K17_8D': {'L': 3.0441000000000003,
#             'offsets': [2.285600000000045, 2.6369000000000824],
#             'splits': ['XC17900', 'YC17900'],
#             'stubs': ['K17_8D1', 'K17_8D2', 'K17_8D3']},
#  'K18_2A': {'L': 3.0441000000000003,
#             'offsets': [0.32560000000000855, 0.7133999999999787],
#             'splits': ['XC18202', 'YC18203'],
#             'stubs': ['K18_2A1', 'K18_2A2', 'K18_2A3']},
#  'K18_3A': {'L': 3.0441,
#             'offsets': [0.3311999999999671, 0.5811999999999671],
#             'splits': ['XC18302', 'YC18303'],
#             'stubs': ['K18_3A1', 'K18_3A2', 'K18_3A3']},
#  'K18_4A': {'L': 3.0441,
#             'offsets': [0.3268000000000484, 0.5768000000000484],
#             'splits': ['XC18402', 'YC18403'],
#             'stubs': ['K18_4A1', 'K18_4A2', 'K18_4A3']},
#  'K18_5A': {'L': 3.0441000000000003,
#             'offsets': [0.3324000000000069, 0.7418999999999869],
#             'splits': ['XC18502', 'YC18503'],
#             'stubs': ['K18_5A1', 'K18_5A2', 'K18_5A3']},
#  'K18_6A': {'L': 3.0441,
#             'offsets': [0.32799999999997453, 0.7164999999999964],
#             'splits': ['XC18602', 'YC18603'],
#             'stubs': ['K18_6A1', 'K18_6A2', 'K18_6A3']},
#  'K18_7A': {'L': 3.0441000000000003,
#             'offsets': [0.33360000000004675, 0.7134000000000924],
#             'splits': ['XC18702', 'YC18703'],
#             'stubs': ['K18_7A1', 'K18_7A2', 'K18_7A3']},
#  'K18_8A': {'L': 3.0441000000000003,
#             'offsets': [0.32920000000001437, 0.7418999999999869],
#             'splits': ['XC18802', 'YC18803'],
#             'stubs': ['K18_8A1', 'K18_8A2', 'K18_8A3']},
#  'K18_8D': {'L': 3.0441,
#             'offsets': [2.2729000000000497, 2.6369000000000824],
#             'splits': ['XC18900', 'YC18900'],
#             'stubs': ['K18_8D1', 'K18_8D2', 'K18_8D3']},
#  'K19_2A': {'L': 3.0441000000000003,
#             'offsets': [0.32560000000000855, 0.6847999999999956],
#             'splits': ['XC19202', 'YC19203'],
#             'stubs': ['K19_2A1', 'K19_2A2', 'K19_2A3']},
#  'K19_3A': {'L': 3.0441,
#             'offsets': [0.3311999999999671, 0.7006999999999834],
#             'splits': ['XC19302', 'YC19303'],
#             'stubs': ['K19_3A1', 'K19_3A2', 'K19_3A3']},
#  'K19_4A': {'L': 3.0441,
#             'offsets': [0.3268000000000484, 0.7164999999999964],
#             'splits': ['XC19402', 'YC19403'],
#             'stubs': ['K19_4A1', 'K19_4A2', 'K19_4A3']},
#  'K19_4D': {'L': 2.1694,
#             'offsets': [1.5950000000000273, 1.9157000000000153],
#             'splits': ['YC57145', 'YC57146'],
#             'stubs': ['K19_4D1', 'K19_4D2', 'K19_4D3']},
#  'K19_5A': {'L': 3.0441000000000003,
#             'offsets': [0.3324000000000069, 0.7355999999999767],
#             'splits': ['XC19502', 'YC19503'],
#             'stubs': ['K19_5A1', 'K19_5A2', 'K19_5A3']},
#  'K19_6A': {'L': 3.0441000000000003,
#             'offsets': [0.32799999999997453, 0.7133999999999787],
#             'splits': ['XC19602', 'YC19603'],
#             'stubs': ['K19_6A1', 'K19_6A2', 'K19_6A3']},
#  'K19_6D': {'L': 3.0441,
#             'offsets': [0.8424999999999727, 2.3057000000000016],
#             'splits': ['YC19700', 'XC19700'],
#             'stubs': ['K19_6D1', 'K19_6D2', 'K19_6D3']},
#  'L0AF__': {'L': 3.095244,
#             'offsets': [0.058645999999999976,
#                         0.9073198,
#                         0.9073198,
#                         1.547622,
#                         3.034325,
#                         3.095244,
#                         3.095244,
#                         3.095244],
#             'splits': ['DLFDAF',
#                        'XC10311',
#                        'YC10312',
#                        'L0AFMID',
#                        'OUTCPAF',
#                        'FLNGAF2',
#                        'L0AFWAKE',
#                        'L0AFEND'],
#             'stubs': ['L0AF__1',
#                       'L0AF__2',
#                       'L0AF__3',
#                       'L0AF__4',
#                       'L0AF__5',
#                       'L0AF__6',
#                       'L0AF__7']},
#  'L0BF__': {'L': 3.095244,
#             'offsets': [0.05864600000000042,
#                         0.3957741000000006,
#                         0.3957741000000006,
#                         1.5476220000000005,
#                         2.699185000000001,
#                         2.699185000000001,
#                         3.034325000000001,
#                         3.095244000000001,
#                         3.095244000000001,
#                         3.095244000000001,
#                         3.095244000000001,
#                         3.095244000000001],
#             'splits': ['DLFDBF',
#                        'XC10381',
#                        'YC10382',
#                        'L0BFMID',
#                        'XC10411',
#                        'YC10412',
#                        'OUTCPBF',
#                        'FLNGBF2',
#                        'L0BFWAKE',
#                        'L0BFEND',
#                        'ENDINJ',
#                        'BEGDL10'],
#             'stubs': ['L0BF__1',
#                       'L0BF__2',
#                       'L0BF__3',
#                       'L0BF__4',
#                       'L0BF__5',
#                       'L0BF__6']},
#  'L1XF__': {'L': 0.5948,
#             'offsets': [0.2974000000000032,
#                         0.2974000000000032,
#                         0.5948000000000064],
#             'splits': ['XC11304', 'YC11305', 'L1XFEND'],
#             'stubs': ['L1XF__1', 'L1XF__2']},
#  'LAIR': {'L': 1.675292943463,
#           'offsets': [1.6752929434629777,
#                       1.6752929434629777,
#                       1.6752929434629777,
#                       1.6752929434629777],
#           'splits': ['MAINDUMP', 'DBMARK30', 'ENDSPECT20', 'END'],
#           'stubs': ['LAIRG']}}

# %% [markdown]
# # Desplit klystrons

# %%
def lines_from_splits(name, split_ele_dict):
    offsets = split_ele_dict['offsets']
    splits = split_ele_dict['splits']
    stubs = split_ele_dict['stubs']
    L = round(split_ele_dict['L'], 9)
    
    

    
    lines = ['!---------------------', f'! {name} LCAVITY']

    
    ###     lines.append(f'{name}: {stubs[0]}, L = {L}')
    # These don't yet have full elements
    
    # Mark is putting in _full lines for these, so shoun't need special logic
    if name in []: #['L0AF', 'L0BF']:
        #lines.append(f'{name}: {stubs[0]}, L = {L}')
        
        voltage = '+'.join([s.strip()+'[voltage]' for s in stubs])
        
        lines.append(f'{name}: {stubs[0]}, L = {L}, voltage = {voltage}')        
        

    lines.append(f'{name}_full: line = ({name})')
    
    if len(splits) == 0:
        lines.append('! does not contain splitting elements. Consider reforming')
    else:
        lines.append('! contains zero length elements:')
    
    for n, o in zip(splits, offsets):
        o = round(o, 9)
        # This is at the end of the ele. Skip markers that shouldn't be included
        if o == L:
            if n.startswith('BEG'):
                continue
            elif n.startswith('END'):
                continue                
        
        lines.append(f'    {n}[superimpose] = T')
        lines.append(f'    {n}[ref] = {name}')
        lines.append(f'    {n}[ref_origin] = beginning')
        lines.append(f'    {n}[offset] = {o}')
    lines.append('\n')
    
    return lines



CU_LINAC_REPLACEMENTS = {}

for name, ele in SPLIT_ELES.items():
    if any([name.startswith(x) for x in ['K', 'L0A', 'L0B', 'L1X'] ]) :
        
        # Strip off ___ from some of these
        name = name.strip('_')
        
        CU_LINAC_REPLACEMENTS[name] = '\n'.join(lines_from_splits(name, ele))
    
    
    
    #line = '\n'.join(lines_from_splits(name, ele))
    
with open('facet2_linac_replacements.json', 'w') as outfile:
    json.dump(CU_LINAC_REPLACEMENTS, outfile, ensure_ascii=True, indent='  ')

# %%
pprint(CU_LINAC_REPLACEMENTS)
# Out:
# {'K11_2A': '!---------------------\n'
#            '! K11_2A LCAVITY\n'
#            'K11_2A_full: line = (K11_2A)\n'
#            '! contains zero length elements:\n'
#            '    XC11202[superimpose] = T\n'
#            '    XC11202[ref] = K11_2A\n'
#            '    XC11202[ref_origin] = beginning\n'
#            '    XC11202[offset] = 0.3256\n'
#            '    YC11203[superimpose] = T\n'
#            '    YC11203[ref] = K11_2A\n'
#            '    YC11203[ref_origin] = beginning\n'
#            '    YC11203[offset] = 0.6126\n'
#            '\n',
#  'K11_4A': '!---------------------\n'
#            '! K11_4A LCAVITY\n'
#            'K11_4A_full: line = (K11_4A)\n'
#            '! contains zero length elements:\n'
#            '    XC11402[superimpose] = T\n'
#            '    XC11402[ref] = K11_4A\n'
#            '    XC11402[ref_origin] = beginning\n'
#            '    XC11402[offset] = 0.3268\n'
#            '    YC11403[superimpose] = T\n'
#            '    YC11403[ref] = K11_4A\n'
#            '    YC11403[ref_origin] = beginning\n'
#            '    YC11403[offset] = 0.5768\n'
#            '\n',
#  'K11_6A': '!---------------------\n'
#            '! K11_6A LCAVITY\n'
#            'K11_6A_full: line = (K11_6A)\n'
#            '! contains zero length elements:\n'
#            '    XC11602[superimpose] = T\n'
#            '    XC11602[ref] = K11_6A\n'
#            '    XC11602[ref_origin] = beginning\n'
#            '    XC11602[offset] = 0.328\n'
#            '    YC11603[superimpose] = T\n'
#            '    YC11603[ref] = K11_6A\n'
#            '    YC11603[ref_origin] = beginning\n'
#            '    YC11603[offset] = 0.578\n'
#            '\n',
#  'K12_2A': '!---------------------\n'
#            '! K12_2A LCAVITY\n'
#            'K12_2A_full: line = (K12_2A)\n'
#            '! contains zero length elements:\n'
#            '    XC12202[superimpose] = T\n'
#            '    XC12202[ref] = K12_2A\n'
#            '    XC12202[ref_origin] = beginning\n'
#            '    XC12202[offset] = 0.328\n'
#            '    YC12203[superimpose] = T\n'
#            '    YC12203[ref] = K12_2A\n'
#            '    YC12203[ref_origin] = beginning\n'
#            '    YC12203[offset] = 0.578\n'
#            '\n',
#  'K12_3A': '!---------------------\n'
#            '! K12_3A LCAVITY\n'
#            'K12_3A_full: line = (K12_3A)\n'
#            '! contains zero length elements:\n'
#            '    XC12302[superimpose] = T\n'
#            '    XC12302[ref] = K12_3A\n'
#            '    XC12302[ref_origin] = beginning\n'
#            '    XC12302[offset] = 0.3312\n'
#            '    YC12303[superimpose] = T\n'
#            '    YC12303[ref] = K12_3A\n'
#            '    YC12303[ref_origin] = beginning\n'
#            '    YC12303[offset] = 0.5812\n'
#            '\n',
#  'K12_4A': '!---------------------\n'
#            '! K12_4A LCAVITY\n'
#            'K12_4A_full: line = (K12_4A)\n'
#            '! contains zero length elements:\n'
#            '    XC12402[superimpose] = T\n'
#            '    XC12402[ref] = K12_4A\n'
#            '    XC12402[ref_origin] = beginning\n'
#            '    XC12402[offset] = 0.3268\n'
#            '    YC12403[superimpose] = T\n'
#            '    YC12403[ref] = K12_4A\n'
#            '    YC12403[ref_origin] = beginning\n'
#            '    YC12403[offset] = 0.5768\n'
#            '\n',
#  'K12_5A': '!---------------------\n'
#            '! K12_5A LCAVITY\n'
#            'K12_5A_full: line = (K12_5A)\n'
#            '! contains zero length elements:\n'
#            '    XC12502[superimpose] = T\n'
#            '    XC12502[ref] = K12_5A\n'
#            '    XC12502[ref_origin] = beginning\n'
#            '    XC12502[offset] = 0.3324\n'
#            '    YC12503[superimpose] = T\n'
#            '    YC12503[ref] = K12_5A\n'
#            '    YC12503[ref_origin] = beginning\n'
#            '    YC12503[offset] = 0.5824\n'
#            '\n',
#  'K12_6A': '!---------------------\n'
#            '! K12_6A LCAVITY\n'
#            'K12_6A_full: line = (K12_6A)\n'
#            '! contains zero length elements:\n'
#            '    XC12602[superimpose] = T\n'
#            '    XC12602[ref] = K12_6A\n'
#            '    XC12602[ref_origin] = beginning\n'
#            '    XC12602[offset] = 0.328\n'
#            '    YC12603[superimpose] = T\n'
#            '    YC12603[ref] = K12_6A\n'
#            '    YC12603[ref_origin] = beginning\n'
#            '    YC12603[offset] = 0.761\n'
#            '\n',
#  'K12_7A': '!---------------------\n'
#            '! K12_7A LCAVITY\n'
#            'K12_7A_full: line = (K12_7A)\n'
#            '! contains zero length elements:\n'
#            '    XC12702[superimpose] = T\n'
#            '    XC12702[ref] = K12_7A\n'
#            '    XC12702[ref_origin] = beginning\n'
#            '    XC12702[offset] = 0.3336\n'
#            '    YC12703[superimpose] = T\n'
#            '    YC12703[ref] = K12_7A\n'
#            '    YC12703[ref_origin] = beginning\n'
#            '    YC12703[offset] = 0.6911\n'
#            '\n',
#  'K12_8A': '!---------------------\n'
#            '! K12_8A LCAVITY\n'
#            'K12_8A_full: line = (K12_8A)\n'
#            '! contains zero length elements:\n'
#            '    XC12802[superimpose] = T\n'
#            '    XC12802[ref] = K12_8A\n'
#            '    XC12802[ref_origin] = beginning\n'
#            '    XC12802[offset] = 0.3292\n'
#            '    YC12803[superimpose] = T\n'
#            '    YC12803[ref] = K12_8A\n'
#            '    YC12803[ref_origin] = beginning\n'
#            '    YC12803[offset] = 0.7324\n'
#            '\n',
#  'K12_8D': '!---------------------\n'
#            '! K12_8D LCAVITY\n'
#            'K12_8D_full: line = (K12_8D)\n'
#            '! contains zero length elements:\n'
#            '    XC12900[superimpose] = T\n'
#            '    XC12900[ref] = K12_8D\n'
#            '    XC12900[ref_origin] = beginning\n'
#            '    XC12900[offset] = 2.3869\n'
#            '    YC12900[superimpose] = T\n'
#            '    YC12900[ref] = K12_8D\n'
#            '    YC12900[ref_origin] = beginning\n'
#            '    YC12900[offset] = 2.6369\n'
#            '\n',
#  'K13_2A': '!---------------------\n'
#            '! K13_2A LCAVITY\n'
#            'K13_2A_full: line = (K13_2A)\n'
#            '! contains zero length elements:\n'
#            '    XC13202[superimpose] = T\n'
#            '    XC13202[ref] = K13_2A\n'
#            '    XC13202[ref_origin] = beginning\n'
#            '    XC13202[offset] = 0.3256\n'
#            '    YC13203[superimpose] = T\n'
#            '    YC13203[ref] = K13_2A\n'
#            '    YC13203[ref_origin] = beginning\n'
#            '    YC13203[offset] = 0.7102\n'
#            '\n',
#  'K13_3A': '!---------------------\n'
#            '! K13_3A LCAVITY\n'
#            'K13_3A_full: line = (K13_3A)\n'
#            '! contains zero length elements:\n'
#            '    XC13302[superimpose] = T\n'
#            '    XC13302[ref] = K13_3A\n'
#            '    XC13302[ref_origin] = beginning\n'
#            '    XC13302[offset] = 0.3312\n'
#            '    YC13303[superimpose] = T\n'
#            '    YC13303[ref] = K13_3A\n'
#            '    YC13303[ref_origin] = beginning\n'
#            '    YC13303[offset] = 0.7134\n'
#            '\n',
#  'K13_4A': '!---------------------\n'
#            '! K13_4A LCAVITY\n'
#            'K13_4A_full: line = (K13_4A)\n'
#            '! contains zero length elements:\n'
#            '    XC13402[superimpose] = T\n'
#            '    XC13402[ref] = K13_4A\n'
#            '    XC13402[ref_origin] = beginning\n'
#            '    XC13402[offset] = 0.3268\n'
#            '    YC13403[superimpose] = T\n'
#            '    YC13403[ref] = K13_4A\n'
#            '    YC13403[ref_origin] = beginning\n'
#            '    YC13403[offset] = 0.7769\n'
#            '\n',
#  'K13_5A': '!---------------------\n'
#            '! K13_5A LCAVITY\n'
#            'K13_5A_full: line = (K13_5A)\n'
#            '! contains zero length elements:\n'
#            '    XC13502[superimpose] = T\n'
#            '    XC13502[ref] = K13_5A\n'
#            '    XC13502[ref_origin] = beginning\n'
#            '    XC13502[offset] = 0.3324\n'
#            '    YC13503[superimpose] = T\n'
#            '    YC13503[ref] = K13_5A\n'
#            '    YC13503[ref_origin] = beginning\n'
#            '    YC13503[offset] = 0.5824\n'
#            '\n',
#  'K13_6A': '!---------------------\n'
#            '! K13_6A LCAVITY\n'
#            'K13_6A_full: line = (K13_6A)\n'
#            '! contains zero length elements:\n'
#            '    XC13602[superimpose] = T\n'
#            '    XC13602[ref] = K13_6A\n'
#            '    XC13602[ref_origin] = beginning\n'
#            '    XC13602[offset] = 0.328\n'
#            '    YC13603[superimpose] = T\n'
#            '    YC13603[ref] = K13_6A\n'
#            '    YC13603[ref_origin] = beginning\n'
#            '    YC13603[offset] = 0.578\n'
#            '\n',
#  'K13_7A': '!---------------------\n'
#            '! K13_7A LCAVITY\n'
#            'K13_7A_full: line = (K13_7A)\n'
#            '! contains zero length elements:\n'
#            '    XC13702[superimpose] = T\n'
#            '    XC13702[ref] = K13_7A\n'
#            '    XC13702[ref_origin] = beginning\n'
#            '    XC13702[offset] = 0.3336\n'
#            '    YC13703[superimpose] = T\n'
#            '    YC13703[ref] = K13_7A\n'
#            '    YC13703[ref_origin] = beginning\n'
#            '    YC13703[offset] = 0.5836\n'
#            '\n',
#  'K13_8A': '!---------------------\n'
#            '! K13_8A LCAVITY\n'
#            'K13_8A_full: line = (K13_8A)\n'
#            '! contains zero length elements:\n'
#            '    XC13802[superimpose] = T\n'
#            '    XC13802[ref] = K13_8A\n'
#            '    XC13802[ref_origin] = beginning\n'
#            '    XC13802[offset] = 0.3292\n'
#            '    YC13803[superimpose] = T\n'
#            '    YC13803[ref] = K13_8A\n'
#            '    YC13803[ref_origin] = beginning\n'
#            '    YC13803[offset] = 0.7356\n'
#            '\n',
#  'K13_8D': '!---------------------\n'
#            '! K13_8D LCAVITY\n'
#            'K13_8D_full: line = (K13_8D)\n'
#            '! contains zero length elements:\n'
#            '    XC13900[superimpose] = T\n'
#            '    XC13900[ref] = K13_8D\n'
#            '    XC13900[ref_origin] = beginning\n'
#            '    XC13900[offset] = 2.3869\n'
#            '    YC13900[superimpose] = T\n'
#            '    YC13900[ref] = K13_8D\n'
#            '    YC13900[ref_origin] = beginning\n'
#            '    YC13900[offset] = 2.6369\n'
#            '\n',
#  'K14_2A': '!---------------------\n'
#            '! K14_2A LCAVITY\n'
#            'K14_2A_full: line = (K14_2A)\n'
#            '! contains zero length elements:\n'
#            '    XC14202[superimpose] = T\n'
#            '    XC14202[ref] = K14_2A\n'
#            '    XC14202[ref_origin] = beginning\n'
#            '    XC14202[offset] = 0.3256\n'
#            '    YC14203[superimpose] = T\n'
#            '    YC14203[ref] = K14_2A\n'
#            '    YC14203[ref_origin] = beginning\n'
#            '    YC14203[offset] = 0.5756\n'
#            '\n',
#  'K14_3A': '!---------------------\n'
#            '! K14_3A LCAVITY\n'
#            'K14_3A_full: line = (K14_3A)\n'
#            '! contains zero length elements:\n'
#            '    XC14302[superimpose] = T\n'
#            '    XC14302[ref] = K14_3A\n'
#            '    XC14302[ref_origin] = beginning\n'
#            '    XC14302[offset] = 0.3312\n'
#            '    YC14303[superimpose] = T\n'
#            '    YC14303[ref] = K14_3A\n'
#            '    YC14303[ref_origin] = beginning\n'
#            '    YC14303[offset] = 0.7324\n'
#            '\n',
#  'K14_4A': '!---------------------\n'
#            '! K14_4A LCAVITY\n'
#            'K14_4A_full: line = (K14_4A)\n'
#            '! contains zero length elements:\n'
#            '    XC14402[superimpose] = T\n'
#            '    XC14402[ref] = K14_4A\n'
#            '    XC14402[ref_origin] = beginning\n'
#            '    XC14402[offset] = 0.3268\n'
#            '    YC14403[superimpose] = T\n'
#            '    YC14403[ref] = K14_4A\n'
#            '    YC14403[ref_origin] = beginning\n'
#            '    YC14403[offset] = 0.5768\n'
#            '\n',
#  'K14_5A': '!---------------------\n'
#            '! K14_5A LCAVITY\n'
#            'K14_5A_full: line = (K14_5A)\n'
#            '! contains zero length elements:\n'
#            '    XC14502[superimpose] = T\n'
#            '    XC14502[ref] = K14_5A\n'
#            '    XC14502[ref_origin] = beginning\n'
#            '    XC14502[offset] = 0.3324\n'
#            '    YC14503[superimpose] = T\n'
#            '    YC14503[ref] = K14_5A\n'
#            '    YC14503[ref_origin] = beginning\n'
#            '    YC14503[offset] = 0.5824\n'
#            '\n',
#  'K14_6A': '!---------------------\n'
#            '! K14_6A LCAVITY\n'
#            'K14_6A_full: line = (K14_6A)\n'
#            '! contains zero length elements:\n'
#            '    XC14602[superimpose] = T\n'
#            '    XC14602[ref] = K14_6A\n'
#            '    XC14602[ref_origin] = beginning\n'
#            '    XC14602[offset] = 0.328\n'
#            '    YC14603[superimpose] = T\n'
#            '    YC14603[ref] = K14_6A\n'
#            '    YC14603[ref_origin] = beginning\n'
#            '    YC14603[offset] = 0.7324\n'
#            '\n',
#  'K14_6D': '!---------------------\n'
#            '! K14_6D LCAVITY\n'
#            'K14_6D_full: line = (K14_6D)\n'
#            '! contains zero length elements:\n'
#            '    XC14702[superimpose] = T\n'
#            '    XC14702[ref] = K14_6D\n'
#            '    XC14702[ref_origin] = beginning\n'
#            '    XC14702[offset] = 2.3321\n'
#            '    YC14703[superimpose] = T\n'
#            '    YC14703[ref] = K14_6D\n'
#            '    YC14703[ref_origin] = beginning\n'
#            '    YC14703[offset] = 2.6369\n'
#            '    LI14TERM[superimpose] = T\n'
#            '    LI14TERM[ref] = K14_6D\n'
#            '    LI14TERM[ref_origin] = beginning\n'
#            '    LI14TERM[offset] = 3.0441\n'
#            '\n',
#  'K15_1A': '!---------------------\n'
#            '! K15_1A LCAVITY\n'
#            'K15_1A_full: line = (K15_1A)\n'
#            '! contains zero length elements:\n'
#            '    XC14900[superimpose] = T\n'
#            '    XC14900[ref] = K15_1A\n'
#            '    XC14900[ref_origin] = beginning\n'
#            '    XC14900[offset] = 0.33\n'
#            '    YC14900[superimpose] = T\n'
#            '    YC14900[ref] = K15_1A\n'
#            '    YC14900[ref_origin] = beginning\n'
#            '    YC14900[offset] = 0.58\n'
#            '\n',
#  'K15_2A': '!---------------------\n'
#            '! K15_2A LCAVITY\n'
#            'K15_2A_full: line = (K15_2A)\n'
#            '! contains zero length elements:\n'
#            '    XC15202[superimpose] = T\n'
#            '    XC15202[ref] = K15_2A\n'
#            '    XC15202[ref_origin] = beginning\n'
#            '    XC15202[offset] = 0.3256\n'
#            '    YC15203[superimpose] = T\n'
#            '    YC15203[ref] = K15_2A\n'
#            '    YC15203[ref_origin] = beginning\n'
#            '    YC15203[offset] = 0.5756\n'
#            '\n',
#  'K15_3A': '!---------------------\n'
#            '! K15_3A LCAVITY\n'
#            'K15_3A_full: line = (K15_3A)\n'
#            '! contains zero length elements:\n'
#            '    XC15302[superimpose] = T\n'
#            '    XC15302[ref] = K15_3A\n'
#            '    XC15302[ref_origin] = beginning\n'
#            '    XC15302[offset] = 0.3312\n'
#            '    YC15303[superimpose] = T\n'
#            '    YC15303[ref] = K15_3A\n'
#            '    YC15303[ref_origin] = beginning\n'
#            '    YC15303[offset] = 0.7356\n'
#            '\n',
#  'K15_4A': '!---------------------\n'
#            '! K15_4A LCAVITY\n'
#            'K15_4A_full: line = (K15_4A)\n'
#            '! contains zero length elements:\n'
#            '    XC15402[superimpose] = T\n'
#            '    XC15402[ref] = K15_4A\n'
#            '    XC15402[ref_origin] = beginning\n'
#            '    XC15402[offset] = 0.3268\n'
#            '    YC15403[superimpose] = T\n'
#            '    YC15403[ref] = K15_4A\n'
#            '    YC15403[ref_origin] = beginning\n'
#            '    YC15403[offset] = 0.5768\n'
#            '\n',
#  'K15_5A': '!---------------------\n'
#            '! K15_5A LCAVITY\n'
#            'K15_5A_full: line = (K15_5A)\n'
#            '! contains zero length elements:\n'
#            '    XC15502[superimpose] = T\n'
#            '    XC15502[ref] = K15_5A\n'
#            '    XC15502[ref_origin] = beginning\n'
#            '    XC15502[offset] = 0.3324\n'
#            '    YC15503[superimpose] = T\n'
#            '    YC15503[ref] = K15_5A\n'
#            '    YC15503[ref_origin] = beginning\n'
#            '    YC15503[offset] = 0.7261\n'
#            '\n',
#  'K15_6A': '!---------------------\n'
#            '! K15_6A LCAVITY\n'
#            'K15_6A_full: line = (K15_6A)\n'
#            '! contains zero length elements:\n'
#            '    XC15602[superimpose] = T\n'
#            '    XC15602[ref] = K15_6A\n'
#            '    XC15602[ref_origin] = beginning\n'
#            '    XC15602[offset] = 0.328\n'
#            '    YC15603[superimpose] = T\n'
#            '    YC15603[ref] = K15_6A\n'
#            '    YC15603[ref_origin] = beginning\n'
#            '    YC15603[offset] = 0.578\n'
#            '\n',
#  'K15_7A': '!---------------------\n'
#            '! K15_7A LCAVITY\n'
#            'K15_7A_full: line = (K15_7A)\n'
#            '! contains zero length elements:\n'
#            '    XC15702[superimpose] = T\n'
#            '    XC15702[ref] = K15_7A\n'
#            '    XC15702[ref_origin] = beginning\n'
#            '    XC15702[offset] = 0.3336\n'
#            '    YC15703[superimpose] = T\n'
#            '    YC15703[ref] = K15_7A\n'
#            '    YC15703[ref_origin] = beginning\n'
#            '    YC15703[offset] = 0.5836\n'
#            '\n',
#  'K15_8A': '!---------------------\n'
#            '! K15_8A LCAVITY\n'
#            'K15_8A_full: line = (K15_8A)\n'
#            '! contains zero length elements:\n'
#            '    XC15802[superimpose] = T\n'
#            '    XC15802[ref] = K15_8A\n'
#            '    XC15802[ref_origin] = beginning\n'
#            '    XC15802[offset] = 0.3292\n'
#            '    YC15803[superimpose] = T\n'
#            '    YC15803[ref] = K15_8A\n'
#            '    YC15803[ref_origin] = beginning\n'
#            '    YC15803[offset] = 0.7705\n'
#            '\n',
#  'K15_8D': '!---------------------\n'
#            '! K15_8D LCAVITY\n'
#            'K15_8D_full: line = (K15_8D)\n'
#            '! contains zero length elements:\n'
#            '    XC15900[superimpose] = T\n'
#            '    XC15900[ref] = K15_8D\n'
#            '    XC15900[ref_origin] = beginning\n'
#            '    XC15900[offset] = 2.3869\n'
#            '    YC15900[superimpose] = T\n'
#            '    YC15900[ref] = K15_8D\n'
#            '    YC15900[ref_origin] = beginning\n'
#            '    YC15900[offset] = 2.6369\n'
#            '\n',
#  'K16_2A': '!---------------------\n'
#            '! K16_2A LCAVITY\n'
#            'K16_2A_full: line = (K16_2A)\n'
#            '! contains zero length elements:\n'
#            '    XC16202[superimpose] = T\n'
#            '    XC16202[ref] = K16_2A\n'
#            '    XC16202[ref_origin] = beginning\n'
#            '    XC16202[offset] = 0.3256\n'
#            '    YC16203[superimpose] = T\n'
#            '    YC16203[ref] = K16_2A\n'
#            '    YC16203[ref_origin] = beginning\n'
#            '    YC16203[offset] = 0.6911\n'
#            '\n',
#  'K16_3A': '!---------------------\n'
#            '! K16_3A LCAVITY\n'
#            'K16_3A_full: line = (K16_3A)\n'
#            '! contains zero length elements:\n'
#            '    XC16302[superimpose] = T\n'
#            '    XC16302[ref] = K16_3A\n'
#            '    XC16302[ref_origin] = beginning\n'
#            '    XC16302[offset] = 0.3312\n'
#            '    YC16303[superimpose] = T\n'
#            '    YC16303[ref] = K16_3A\n'
#            '    YC16303[ref_origin] = beginning\n'
#            '    YC16303[offset] = 0.5812\n'
#            '\n',
#  'K16_4A': '!---------------------\n'
#            '! K16_4A LCAVITY\n'
#            'K16_4A_full: line = (K16_4A)\n'
#            '! contains zero length elements:\n'
#            '    XC16402[superimpose] = T\n'
#            '    XC16402[ref] = K16_4A\n'
#            '    XC16402[ref_origin] = beginning\n'
#            '    XC16402[offset] = 0.3268\n'
#            '    YC16403[superimpose] = T\n'
#            '    YC16403[ref] = K16_4A\n'
#            '    YC16403[ref_origin] = beginning\n'
#            '    YC16403[offset] = 0.6943\n'
#            '\n',
#  'K16_5A': '!---------------------\n'
#            '! K16_5A LCAVITY\n'
#            'K16_5A_full: line = (K16_5A)\n'
#            '! contains zero length elements:\n'
#            '    XC16502[superimpose] = T\n'
#            '    XC16502[ref] = K16_5A\n'
#            '    XC16502[ref_origin] = beginning\n'
#            '    XC16502[offset] = 0.3324\n'
#            '    YC16503[superimpose] = T\n'
#            '    YC16503[ref] = K16_5A\n'
#            '    YC16503[ref_origin] = beginning\n'
#            '    YC16503[offset] = 0.6975\n'
#            '\n',
#  'K16_6A': '!---------------------\n'
#            '! K16_6A LCAVITY\n'
#            'K16_6A_full: line = (K16_6A)\n'
#            '! contains zero length elements:\n'
#            '    XC16602[superimpose] = T\n'
#            '    XC16602[ref] = K16_6A\n'
#            '    XC16602[ref_origin] = beginning\n'
#            '    XC16602[offset] = 0.328\n'
#            '    YC16603[superimpose] = T\n'
#            '    YC16603[ref] = K16_6A\n'
#            '    YC16603[ref_origin] = beginning\n'
#            '    YC16603[offset] = 0.7419\n'
#            '\n',
#  'K16_7A': '!---------------------\n'
#            '! K16_7A LCAVITY\n'
#            'K16_7A_full: line = (K16_7A)\n'
#            '! contains zero length elements:\n'
#            '    XC16702[superimpose] = T\n'
#            '    XC16702[ref] = K16_7A\n'
#            '    XC16702[ref_origin] = beginning\n'
#            '    XC16702[offset] = 0.3336\n'
#            '    YC16703[superimpose] = T\n'
#            '    YC16703[ref] = K16_7A\n'
#            '    YC16703[ref_origin] = beginning\n'
#            '    YC16703[offset] = 0.7229\n'
#            '\n',
#  'K16_8A': '!---------------------\n'
#            '! K16_8A LCAVITY\n'
#            'K16_8A_full: line = (K16_8A)\n'
#            '! contains zero length elements:\n'
#            '    XC16802[superimpose] = T\n'
#            '    XC16802[ref] = K16_8A\n'
#            '    XC16802[ref_origin] = beginning\n'
#            '    XC16802[offset] = 0.3292\n'
#            '    YC16803[superimpose] = T\n'
#            '    YC16803[ref] = K16_8A\n'
#            '    YC16803[ref_origin] = beginning\n'
#            '    YC16803[offset] = 0.5792\n'
#            '\n',
#  'K16_8D': '!---------------------\n'
#            '! K16_8D LCAVITY\n'
#            'K16_8D_full: line = (K16_8D)\n'
#            '! contains zero length elements:\n'
#            '    XC16900[superimpose] = T\n'
#            '    XC16900[ref] = K16_8D\n'
#            '    XC16900[ref_origin] = beginning\n'
#            '    XC16900[offset] = 2.3869\n'
#            '    YC16900[superimpose] = T\n'
#            '    YC16900[ref] = K16_8D\n'
#            '    YC16900[ref_origin] = beginning\n'
#            '    YC16900[offset] = 2.6369\n'
#            '\n',
#  'K17_2A': '!---------------------\n'
#            '! K17_2A LCAVITY\n'
#            'K17_2A_full: line = (K17_2A)\n'
#            '! contains zero length elements:\n'
#            '    XC17202[superimpose] = T\n'
#            '    XC17202[ref] = K17_2A\n'
#            '    XC17202[ref_origin] = beginning\n'
#            '    XC17202[offset] = 0.3256\n'
#            '    YC17203[superimpose] = T\n'
#            '    YC17203[ref] = K17_2A\n'
#            '    YC17203[ref_origin] = beginning\n'
#            '    YC17203[offset] = 0.707\n'
#            '\n',
#  'K17_3A': '!---------------------\n'
#            '! K17_3A LCAVITY\n'
#            'K17_3A_full: line = (K17_3A)\n'
#            '! contains zero length elements:\n'
#            '    XC17302[superimpose] = T\n'
#            '    XC17302[ref] = K17_3A\n'
#            '    XC17302[ref_origin] = beginning\n'
#            '    XC17302[offset] = 0.3312\n'
#            '    YC17303[superimpose] = T\n'
#            '    YC17303[ref] = K17_3A\n'
#            '    YC17303[ref_origin] = beginning\n'
#            '    YC17303[offset] = 0.5812\n'
#            '\n',
#  'K17_4A': '!---------------------\n'
#            '! K17_4A LCAVITY\n'
#            'K17_4A_full: line = (K17_4A)\n'
#            '! contains zero length elements:\n'
#            '    XC17402[superimpose] = T\n'
#            '    XC17402[ref] = K17_4A\n'
#            '    XC17402[ref_origin] = beginning\n'
#            '    XC17402[offset] = 0.3268\n'
#            '    YC17403[superimpose] = T\n'
#            '    YC17403[ref] = K17_4A\n'
#            '    YC17403[ref_origin] = beginning\n'
#            '    YC17403[offset] = 0.5768\n'
#            '\n',
#  'K17_5A': '!---------------------\n'
#            '! K17_5A LCAVITY\n'
#            'K17_5A_full: line = (K17_5A)\n'
#            '! contains zero length elements:\n'
#            '    XC17502[superimpose] = T\n'
#            '    XC17502[ref] = K17_5A\n'
#            '    XC17502[ref_origin] = beginning\n'
#            '    XC17502[offset] = 0.3324\n'
#            '    YC17503[superimpose] = T\n'
#            '    YC17503[ref] = K17_5A\n'
#            '    YC17503[ref_origin] = beginning\n'
#            '    YC17503[offset] = 0.7165\n'
#            '\n',
#  'K17_6A': '!---------------------\n'
#            '! K17_6A LCAVITY\n'
#            'K17_6A_full: line = (K17_6A)\n'
#            '! contains zero length elements:\n'
#            '    XC17602[superimpose] = T\n'
#            '    XC17602[ref] = K17_6A\n'
#            '    XC17602[ref_origin] = beginning\n'
#            '    XC17602[offset] = 0.328\n'
#            '    YC17603[superimpose] = T\n'
#            '    YC17603[ref] = K17_6A\n'
#            '    YC17603[ref_origin] = beginning\n'
#            '    YC17603[offset] = 0.7229\n'
#            '\n',
#  'K17_7A': '!---------------------\n'
#            '! K17_7A LCAVITY\n'
#            'K17_7A_full: line = (K17_7A)\n'
#            '! contains zero length elements:\n'
#            '    XC17702[superimpose] = T\n'
#            '    XC17702[ref] = K17_7A\n'
#            '    XC17702[ref_origin] = beginning\n'
#            '    XC17702[offset] = 0.3336\n'
#            '    YC17703[superimpose] = T\n'
#            '    YC17703[ref] = K17_7A\n'
#            '    YC17703[ref_origin] = beginning\n'
#            '    YC17703[offset] = 0.5836\n'
#            '\n',
#  'K17_8A': '!---------------------\n'
#            '! K17_8A LCAVITY\n'
#            'K17_8A_full: line = (K17_8A)\n'
#            '! contains zero length elements:\n'
#            '    XC17802[superimpose] = T\n'
#            '    XC17802[ref] = K17_8A\n'
#            '    XC17802[ref_origin] = beginning\n'
#            '    XC17802[offset] = 0.3292\n'
#            '    YC17803[superimpose] = T\n'
#            '    YC17803[ref] = K17_8A\n'
#            '    YC17803[ref_origin] = beginning\n'
#            '    YC17803[offset] = 0.5792\n'
#            '\n',
#  'K17_8D': '!---------------------\n'
#            '! K17_8D LCAVITY\n'
#            'K17_8D_full: line = (K17_8D)\n'
#            '! contains zero length elements:\n'
#            '    XC17900[superimpose] = T\n'
#            '    XC17900[ref] = K17_8D\n'
#            '    XC17900[ref_origin] = beginning\n'
#            '    XC17900[offset] = 2.2856\n'
#            '    YC17900[superimpose] = T\n'
#            '    YC17900[ref] = K17_8D\n'
#            '    YC17900[ref_origin] = beginning\n'
#            '    YC17900[offset] = 2.6369\n'
#            '\n',
#  'K18_2A': '!---------------------\n'
#            '! K18_2A LCAVITY\n'
#            'K18_2A_full: line = (K18_2A)\n'
#            '! contains zero length elements:\n'
#            '    XC18202[superimpose] = T\n'
#            '    XC18202[ref] = K18_2A\n'
#            '    XC18202[ref_origin] = beginning\n'
#            '    XC18202[offset] = 0.3256\n'
#            '    YC18203[superimpose] = T\n'
#            '    YC18203[ref] = K18_2A\n'
#            '    YC18203[ref_origin] = beginning\n'
#            '    YC18203[offset] = 0.7134\n'
#            '\n',
#  'K18_3A': '!---------------------\n'
#            '! K18_3A LCAVITY\n'
#            'K18_3A_full: line = (K18_3A)\n'
#            '! contains zero length elements:\n'
#            '    XC18302[superimpose] = T\n'
#            '    XC18302[ref] = K18_3A\n'
#            '    XC18302[ref_origin] = beginning\n'
#            '    XC18302[offset] = 0.3312\n'
#            '    YC18303[superimpose] = T\n'
#            '    YC18303[ref] = K18_3A\n'
#            '    YC18303[ref_origin] = beginning\n'
#            '    YC18303[offset] = 0.5812\n'
#            '\n',
#  'K18_4A': '!---------------------\n'
#            '! K18_4A LCAVITY\n'
#            'K18_4A_full: line = (K18_4A)\n'
#            '! contains zero length elements:\n'
#            '    XC18402[superimpose] = T\n'
#            '    XC18402[ref] = K18_4A\n'
#            '    XC18402[ref_origin] = beginning\n'
#            '    XC18402[offset] = 0.3268\n'
#            '    YC18403[superimpose] = T\n'
#            '    YC18403[ref] = K18_4A\n'
#            '    YC18403[ref_origin] = beginning\n'
#            '    YC18403[offset] = 0.5768\n'
#            '\n',
#  'K18_5A': '!---------------------\n'
#            '! K18_5A LCAVITY\n'
#            'K18_5A_full: line = (K18_5A)\n'
#            '! contains zero length elements:\n'
#            '    XC18502[superimpose] = T\n'
#            '    XC18502[ref] = K18_5A\n'
#            '    XC18502[ref_origin] = beginning\n'
#            '    XC18502[offset] = 0.3324\n'
#            '    YC18503[superimpose] = T\n'
#            '    YC18503[ref] = K18_5A\n'
#            '    YC18503[ref_origin] = beginning\n'
#            '    YC18503[offset] = 0.7419\n'
#            '\n',
#  'K18_6A': '!---------------------\n'
#            '! K18_6A LCAVITY\n'
#            'K18_6A_full: line = (K18_6A)\n'
#            '! contains zero length elements:\n'
#            '    XC18602[superimpose] = T\n'
#            '    XC18602[ref] = K18_6A\n'
#            '    XC18602[ref_origin] = beginning\n'
#            '    XC18602[offset] = 0.328\n'
#            '    YC18603[superimpose] = T\n'
#            '    YC18603[ref] = K18_6A\n'
#            '    YC18603[ref_origin] = beginning\n'
#            '    YC18603[offset] = 0.7165\n'
#            '\n',
#  'K18_7A': '!---------------------\n'
#            '! K18_7A LCAVITY\n'
#            'K18_7A_full: line = (K18_7A)\n'
#            '! contains zero length elements:\n'
#            '    XC18702[superimpose] = T\n'
#            '    XC18702[ref] = K18_7A\n'
#            '    XC18702[ref_origin] = beginning\n'
#            '    XC18702[offset] = 0.3336\n'
#            '    YC18703[superimpose] = T\n'
#            '    YC18703[ref] = K18_7A\n'
#            '    YC18703[ref_origin] = beginning\n'
#            '    YC18703[offset] = 0.7134\n'
#            '\n',
#  'K18_8A': '!---------------------\n'
#            '! K18_8A LCAVITY\n'
#            'K18_8A_full: line = (K18_8A)\n'
#            '! contains zero length elements:\n'
#            '    XC18802[superimpose] = T\n'
#            '    XC18802[ref] = K18_8A\n'
#            '    XC18802[ref_origin] = beginning\n'
#            '    XC18802[offset] = 0.3292\n'
#            '    YC18803[superimpose] = T\n'
#            '    YC18803[ref] = K18_8A\n'
#            '    YC18803[ref_origin] = beginning\n'
#            '    YC18803[offset] = 0.7419\n'
#            '\n',
#  'K18_8D': '!---------------------\n'
#            '! K18_8D LCAVITY\n'
#            'K18_8D_full: line = (K18_8D)\n'
#            '! contains zero length elements:\n'
#            '    XC18900[superimpose] = T\n'
#            '    XC18900[ref] = K18_8D\n'
#            '    XC18900[ref_origin] = beginning\n'
#            '    XC18900[offset] = 2.2729\n'
#            '    YC18900[superimpose] = T\n'
#            '    YC18900[ref] = K18_8D\n'
#            '    YC18900[ref_origin] = beginning\n'
#            '    YC18900[offset] = 2.6369\n'
#            '\n',
#  'K19_2A': '!---------------------\n'
#            '! K19_2A LCAVITY\n'
#            'K19_2A_full: line = (K19_2A)\n'
#            '! contains zero length elements:\n'
#            '    XC19202[superimpose] = T\n'
#            '    XC19202[ref] = K19_2A\n'
#            '    XC19202[ref_origin] = beginning\n'
#            '    XC19202[offset] = 0.3256\n'
#            '    YC19203[superimpose] = T\n'
#            '    YC19203[ref] = K19_2A\n'
#            '    YC19203[ref_origin] = beginning\n'
#            '    YC19203[offset] = 0.6848\n'
#            '\n',
#  'K19_3A': '!---------------------\n'
#            '! K19_3A LCAVITY\n'
#            'K19_3A_full: line = (K19_3A)\n'
#            '! contains zero length elements:\n'
#            '    XC19302[superimpose] = T\n'
#            '    XC19302[ref] = K19_3A\n'
#            '    XC19302[ref_origin] = beginning\n'
#            '    XC19302[offset] = 0.3312\n'
#            '    YC19303[superimpose] = T\n'
#            '    YC19303[ref] = K19_3A\n'
#            '    YC19303[ref_origin] = beginning\n'
#            '    YC19303[offset] = 0.7007\n'
#            '\n',
#  'K19_4A': '!---------------------\n'
#            '! K19_4A LCAVITY\n'
#            'K19_4A_full: line = (K19_4A)\n'
#            '! contains zero length elements:\n'
#            '    XC19402[superimpose] = T\n'
#            '    XC19402[ref] = K19_4A\n'
#            '    XC19402[ref_origin] = beginning\n'
#            '    XC19402[offset] = 0.3268\n'
#            '    YC19403[superimpose] = T\n'
#            '    YC19403[ref] = K19_4A\n'
#            '    YC19403[ref_origin] = beginning\n'
#            '    YC19403[offset] = 0.7165\n'
#            '\n',
#  'K19_4D': '!---------------------\n'
#            '! K19_4D LCAVITY\n'
#            'K19_4D_full: line = (K19_4D)\n'
#            '! contains zero length elements:\n'
#            '    YC57145[superimpose] = T\n'
#            '    YC57145[ref] = K19_4D\n'
#            '    YC57145[ref_origin] = beginning\n'
#            '    YC57145[offset] = 1.595\n'
#            '    YC57146[superimpose] = T\n'
#            '    YC57146[ref] = K19_4D\n'
#            '    YC57146[ref_origin] = beginning\n'
#            '    YC57146[offset] = 1.9157\n'
#            '\n',
#  'K19_5A': '!---------------------\n'
#            '! K19_5A LCAVITY\n'
#            'K19_5A_full: line = (K19_5A)\n'
#            '! contains zero length elements:\n'
#            '    XC19502[superimpose] = T\n'
#            '    XC19502[ref] = K19_5A\n'
#            '    XC19502[ref_origin] = beginning\n'
#            '    XC19502[offset] = 0.3324\n'
#            '    YC19503[superimpose] = T\n'
#            '    YC19503[ref] = K19_5A\n'
#            '    YC19503[ref_origin] = beginning\n'
#            '    YC19503[offset] = 0.7356\n'
#            '\n',
#  'K19_6A': '!---------------------\n'
#            '! K19_6A LCAVITY\n'
#            'K19_6A_full: line = (K19_6A)\n'
#            '! contains zero length elements:\n'
#            '    XC19602[superimpose] = T\n'
#            '    XC19602[ref] = K19_6A\n'
#            '    XC19602[ref_origin] = beginning\n'
#            '    XC19602[offset] = 0.328\n'
#            '    YC19603[superimpose] = T\n'
#            '    YC19603[ref] = K19_6A\n'
#            '    YC19603[ref_origin] = beginning\n'
#            '    YC19603[offset] = 0.7134\n'
#            '\n',
#  'K19_6D': '!---------------------\n'
#            '! K19_6D LCAVITY\n'
#            'K19_6D_full: line = (K19_6D)\n'
#            '! contains zero length elements:\n'
#            '    YC19700[superimpose] = T\n'
#            '    YC19700[ref] = K19_6D\n'
#            '    YC19700[ref_origin] = beginning\n'
#            '    YC19700[offset] = 0.8425\n'
#            '    XC19700[superimpose] = T\n'
#            '    XC19700[ref] = K19_6D\n'
#            '    XC19700[ref_origin] = beginning\n'
#            '    XC19700[offset] = 2.3057\n'
#            '\n',
#  'L0AF': '!---------------------\n'
#          '! L0AF LCAVITY\n'
#          'L0AF_full: line = (L0AF)\n'
#          '! contains zero length elements:\n'
#          '    DLFDAF[superimpose] = T\n'
#          '    DLFDAF[ref] = L0AF\n'
#          '    DLFDAF[ref_origin] = beginning\n'
#          '    DLFDAF[offset] = 0.058646\n'
#          '    XC10311[superimpose] = T\n'
#          '    XC10311[ref] = L0AF\n'
#          '    XC10311[ref_origin] = beginning\n'
#          '    XC10311[offset] = 0.9073198\n'
#          '    YC10312[superimpose] = T\n'
#          '    YC10312[ref] = L0AF\n'
#          '    YC10312[ref_origin] = beginning\n'
#          '    YC10312[offset] = 0.9073198\n'
#          '    L0AFMID[superimpose] = T\n'
#          '    L0AFMID[ref] = L0AF\n'
#          '    L0AFMID[ref_origin] = beginning\n'
#          '    L0AFMID[offset] = 1.547622\n'
#          '    OUTCPAF[superimpose] = T\n'
#          '    OUTCPAF[ref] = L0AF\n'
#          '    OUTCPAF[ref_origin] = beginning\n'
#          '    OUTCPAF[offset] = 3.034325\n'
#          '    FLNGAF2[superimpose] = T\n'
#          '    FLNGAF2[ref] = L0AF\n'
#          '    FLNGAF2[ref_origin] = beginning\n'
#          '    FLNGAF2[offset] = 3.095244\n'
#          '    L0AFWAKE[superimpose] = T\n'
#          '    L0AFWAKE[ref] = L0AF\n'
#          '    L0AFWAKE[ref_origin] = beginning\n'
#          '    L0AFWAKE[offset] = 3.095244\n'
#          '    L0AFEND[superimpose] = T\n'
#          '    L0AFEND[ref] = L0AF\n'
#          '    L0AFEND[ref_origin] = beginning\n'
#          '    L0AFEND[offset] = 3.095244\n'
#          '\n',
#  'L0BF': '!---------------------\n'
#          '! L0BF LCAVITY\n'
#          'L0BF_full: line = (L0BF)\n'
#          '! contains zero length elements:\n'
#          '    DLFDBF[superimpose] = T\n'
#          '    DLFDBF[ref] = L0BF\n'
#          '    DLFDBF[ref_origin] = beginning\n'
#          '    DLFDBF[offset] = 0.058646\n'
#          '    XC10381[superimpose] = T\n'
#          '    XC10381[ref] = L0BF\n'
#          '    XC10381[ref_origin] = beginning\n'
#          '    XC10381[offset] = 0.3957741\n'
#          '    YC10382[superimpose] = T\n'
#          '    YC10382[ref] = L0BF\n'
#          '    YC10382[ref_origin] = beginning\n'
#          '    YC10382[offset] = 0.3957741\n'
#          '    L0BFMID[superimpose] = T\n'
#          '    L0BFMID[ref] = L0BF\n'
#          '    L0BFMID[ref_origin] = beginning\n'
#          '    L0BFMID[offset] = 1.547622\n'
#          '    XC10411[superimpose] = T\n'
#          '    XC10411[ref] = L0BF\n'
#          '    XC10411[ref_origin] = beginning\n'
#          '    XC10411[offset] = 2.699185\n'
#          '    YC10412[superimpose] = T\n'
#          '    YC10412[ref] = L0BF\n'
#          '    YC10412[ref_origin] = beginning\n'
#          '    YC10412[offset] = 2.699185\n'
#          '    OUTCPBF[superimpose] = T\n'
#          '    OUTCPBF[ref] = L0BF\n'
#          '    OUTCPBF[ref_origin] = beginning\n'
#          '    OUTCPBF[offset] = 3.034325\n'
#          '    FLNGBF2[superimpose] = T\n'
#          '    FLNGBF2[ref] = L0BF\n'
#          '    FLNGBF2[ref_origin] = beginning\n'
#          '    FLNGBF2[offset] = 3.095244\n'
#          '    L0BFWAKE[superimpose] = T\n'
#          '    L0BFWAKE[ref] = L0BF\n'
#          '    L0BFWAKE[ref_origin] = beginning\n'
#          '    L0BFWAKE[offset] = 3.095244\n'
#          '    L0BFEND[superimpose] = T\n'
#          '    L0BFEND[ref] = L0BF\n'
#          '    L0BFEND[ref_origin] = beginning\n'
#          '    L0BFEND[offset] = 3.095244\n'
#          '\n',
#  'L1XF': '!---------------------\n'
#          '! L1XF LCAVITY\n'
#          'L1XF_full: line = (L1XF)\n'
#          '! contains zero length elements:\n'
#          '    XC11304[superimpose] = T\n'
#          '    XC11304[ref] = L1XF\n'
#          '    XC11304[ref_origin] = beginning\n'
#          '    XC11304[offset] = 0.2974\n'
#          '    YC11305[superimpose] = T\n'
#          '    YC11305[ref] = L1XF\n'
#          '    YC11305[ref_origin] = beginning\n'
#          '    YC11305[offset] = 0.2974\n'
#          '    L1XFEND[superimpose] = T\n'
#          '    L1XFEND[ref] = L1XF\n'
#          '    L1XFEND[ref_origin] = beginning\n'
#          '    L1XFEND[offset] = 0.5948\n'
#          '\n'}

# %%
# !mv facet2_linac_replacements.json good_facet2_linac_replacements.json
